# %%
# %config Completer.use_jedi=False
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline

# %%
serie_biv= pd.read_csv('C:/Users/Administrateur/Desktop/Ex_stadist/serie_biv.csv')

# %%
display(serie_biv)
# Out:
#           month  Num_Acc  Nb_morts
# 0    2005-03-01    10144       151
# 1    2005-04-01    10313       135
# 2    2005-05-01    12102       166
# 3    2005-06-01    12972       196
# 4    2005-07-01    12180       295
# ..          ...      ...       ...
# 143  2017-02-01     6097       152
# 144  2017-03-01     7828       197
# 145  2017-04-01     7950       182
# 146  2017-05-01     7999       221
# 147  2017-06-01     9181       246
#
# [148 rows x 3 columns]

# %%
serie_biv=serie_biv.drop('month',axis=1)

# %%
display(serie_biv)
# Out:
#      Num_Acc  Nb_morts
# 0      10144       151
# 1      10313       135
# 2      12102       166
# 3      12972       196
# 4      12180       295
# ..       ...       ...
# 143     6097       152
# 144     7828       197
# 145     7950       182
# 146     7999       221
# 147     9181       246
#
# [148 rows x 2 columns]

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
data =serie_biv
# Fit the Exponential Smoothing model
model = ExponentialSmoothing(data['Num_Acc'], seasonal='add', seasonal_periods=12)
model_fit = model.fit()
# Forecast future values
forecast = model_fit.forecast(steps=5)
# Plot the forecasted values
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Num_Acc'], label='Historical Values')
plt.plot(range(len(data), len(data) + 5), forecast, 'r--', label='Forecasted Values')
plt.legend()
plt.title('Univariate Forecast using Exponential Smoothing')
plt.xlabel('Time')
plt.ylabel('Num_Acc')
plt.show()

# %%
Serie accidents originale sans corriger

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
Serie morts originale sans corriger

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
data =serie_biv
# Fit the Exponential Smoothing model
model = ExponentialSmoothing(data['Nb_morts'], seasonal='add', seasonal_periods=12)
model_fit = model.fit()
# Forecast future values
forecast = model_fit.forecast(steps=5)
# Plot the forecasted values
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Nb_morts'], label='Historical Values')
plt.plot(range(len(data), len(data) + 5), forecast, 'r--', label='Forecasted Values')
plt.legend()
plt.title('Univariate Forecast using Exponential Smoothing')
plt.xlabel('Time')
plt.ylabel('Nb_morts')
plt.show()

# %% [markdown]
# ![Model_comparison.PNG](attachment:Model_comparison.PNG)

# %% [markdown]
#  Conclusion
#  Choosing the right method depends on your specific data and forecasting objectives, so take the time to explore and experiment with these methods to make informed predictions for your domain.
